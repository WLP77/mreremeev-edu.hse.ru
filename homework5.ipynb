# %%
date_formats = [
    "%A, %B %d, %Y",
    "%A, %d.%m.%y",
    "%A, %d %B %Y"
]

print("Введите дату в одном из форматов газет. Примеры:")
print("1)Wednesday, October 2, 2002")
print("2)Friday, 11.10.13")
print("3)Thursday, 18 August 1977")
print("Для выхода введите «q».")

while True:
    user_input = input("\nВведите дату (или «q» для выхода): ").strip()
    
    if user_input.lower() == "q":
        print("Программа завершена.")
        break

    parsed = None

    for fmt in date_formats:
        try:
            parsed = datetime.strptime(user_input, fmt)
            break
        except ValueError:
            continue

    if parsed is not None:
        print("Распознанная дата:", parsed.date())
    else:
        print("Не удалось распознать дату. Попробуйте ещё раз.")
# Out:
# Введите дату в одном из форматов газет. Примеры:
# 1)Wednesday, October 2, 2002
# 2)Friday, 11.10.13
# 3)Thursday, 18 August 1977
# Для выхода введите «q».
# Введите дату (или «q» для выхода):  Wednesday, October 2, 2002
# Распознанная дата: 2002-10-02
# Введите дату (или «q» для выхода):  ber 2, 2002
# Не удалось распознать дату. Попробуйте ещё раз.
# Введите дату (или «q» для выхода):  q
# Программа завершена.
